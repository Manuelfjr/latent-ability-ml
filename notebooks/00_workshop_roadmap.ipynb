# %% [markdown]
# # Workshop Roadmap: Supervised Evaluation, IRT, and CLAIRE
#
# This notebook frames the hands-on session for Bristol CDT students.
# It is intentionally light and should be polished after the technical notebooks are more mature.

# %% [markdown]
# ## Session Narrative
#
# 1. Why standard supervised evaluation can be misleading.
# 2. Why latent ability matters.
# 3. How IRT helps model difficulty and ability.
# 4. Where Beta4 enters the story.
# 5. How CLAIRE addresses the problem in your proposed framework.

# %% [markdown]
# ## Learning Goals
#
# - compare standard evaluation metrics under controlled toy settings;
# - build intuition for item difficulty and latent ability;
# - interpret ICCs visually;
# - connect the supervised-learning setting to CLAIRE.

# %%
from workshop_utils import set_project_root

PROJECT_ROOT = set_project_root()

# %% [markdown]
# ## Presenter Notes
#
# - Add a one-slide motivation for the CDT audience.
# - Clarify whether Beta4 will be introduced formally or only intuitively.
# - Add the exact definition of CLAIRE once the final exposition order is decided.
