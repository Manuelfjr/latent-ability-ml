# %% [markdown]
# <table width="100%">
#   <tr>
#     <td align="left" valign="middle" width="100%">
#       <img src="../docs/assets/logo_bristol.png" alt="University of Bristol" width="200" />
#     </td>
#     <td align="right" valign="middle" width="100%">
#       <img src="../docs/assets/logo_ufpe.png" alt="UFPE" width="130" />
#       &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;
#       <img src="../docs/assets/logo_kunumi.png" alt="Kunumi" width="150" />
#       &nbsp;&nbsp;
#     </td>
#   </tr>
# </table>
#
# ---

# %%
import subprocess
import sys
from pathlib import Path

IN_COLAB = 'google.colab' in sys.modules

if IN_COLAB:
    REPO_ROOT = Path('/content/latent-ability-ml')
    if not REPO_ROOT.exists():
        subprocess.check_call([
            'git',
            'clone',
            'https://github.com/manuelfjr/latent-ability-ml.git',
            str(REPO_ROOT),
        ])

    subprocess.check_call([
        sys.executable,
        '-m',
        'pip',
        'install',
        '-q',
        'numpy',
        'pandas',
        'matplotlib',
        'scipy',
        'scikit-learn',
        'seaborn',
        'joblib',
        'tqdm',
        'birt-gd',
    ])

    for candidate in [REPO_ROOT, REPO_ROOT / 'notebooks', REPO_ROOT / 'utils', REPO_ROOT / 'src']:
        candidate_str = str(candidate)
        if candidate_str not in sys.path:
            sys.path.insert(0, candidate_str)

    from nb_utils import set_root
    PROJECT_ROOT = REPO_ROOT
    print(f'Running in Colab with project root: {PROJECT_ROOT}')
else:
    from nb_utils import set_root
    PROJECT_ROOT = set_root(level=2)
    print(f'Running locally with project root: {PROJECT_ROOT}')

# %% [markdown]
# **Environment note.** Run the next code cell first. It loads the repository and the local modules needed for this notebook, especially when opening it in Google Colab.

# %% [markdown]
# # Activity 1: Supervised Evaluation and Example Difficulty
#
# Use this notebook after Section 1. The goal is to compare a small supervised model pool and identify which examples remain difficult even when aggregate metrics look acceptable.

# %% [markdown]
# ## Activity Goals
#
# By the end of this notebook, you should be able to:
#
# - generate or adapt a toy classification dataset;
# - compare several supervised models using compact metric summaries;
# - inspect which examples are ambiguous or disagreement-prone;
# - discuss why local difficulty matters even in supervised evaluation.

# %%
# answer

# %% [markdown]
# ## Task 1
#
# Create a toy classification dataset. You may change class separation, label noise, class balance, or random seed.
#
# In addition to coding, discuss what kind of classification problem you are creating.

# %%
# answer

# %% [markdown]
# ## Task 2
#
# Evaluate a small pool of supervised models on your dataset and compare the metrics.
#
# In addition to computing the table, discuss whether the metrics tell the same story.

# %%
# answer

# %% [markdown]
# ## Task 3
#
# Inspect example-level difficulty or disagreement.
#
# In addition to plotting the result, discuss where the hard examples are and why they may be difficult.

# %%
# answer
