# %%
from nb_utils import set_root

PROJECT_ROOT = set_root(level=2)

# %% [markdown]
# # Activity 1: Supervised Evaluation Beyond Accuracy
#
# Use this notebook after Section 1. The goal is to create a third scenario and decide whether aggregate metrics tell the full story.

# %%
import matplotlib.pyplot as plt
import pandas as pd

from utils.handson import (
    evaluate_models_on_dataset,
    make_toy_classification_dataset,
    plot_classification_dataset,
    plot_example_difficulty,
    summarize_classification_results,
    summarize_instance_difficulty,
)

# %% [markdown]
# ## Starter Scenario
#
# This baseline sits between the easy and hard cases from the guided notebook.

# %% [markdown]
# ## Task 1
#
# Create a **new toy dataset** by changing at least two of the following:
#
# - `class_sep`
# - `flip_y`
# - `weights`
# - `random_state`
#
# > you can use the library scikit-learn (make_classification)

# %%
# answer

# %% [markdown]
# ## Task 2
#
# Evaluate the three models on your scenario and compare the results to the baseline.

# %%
# answer

# %% [markdown]
# ## Task 3
#
# Inspect the hard examples in your scenario and discurss about it.

# %%
# answer

# %% [markdown]
# ## Reflection Questions
#
# 1. Which metric was most stable across scenarios?
# 2. Which model seems most sensitive to hard examples?
# 3. Do the difficult examples appear in obvious overlap regions?
# 4. Why does this motivate a latent-variable view of evaluation?
